# %% [markdown]
# # Project 4
#
# Outline:
#
# * scraping data
#
#
# [pivoting by location. Extract all the locations for further analysis]
#
# * binning
#
# [ exploratory analysis ]
#
# * parsing data
#
# * building model
#
# * evaluating model

# %% [raw]
# # load the library
# from bs4 import BeautifulSoup
# import urllib2, requests
# import pandas as pd
#
# df = pd.DataFrame()   # create a new data frame
# pd.set_option('max_colwidth',500)    # to remove column limit (default is 50. Otherwise, we'll lose some info)
#
#
# # indeed.com's query url
# base_url = 'http://www.indeed.com/jobs?q=data+scientist&jt=fulltime&sort='
# sort_by = 'date'          # sort by data
# start_from = '&start='    # start page number

# %% [markdown]
# Downloading the whole data for US. 09/29/2016

# %% [raw]
# for page in range(1,1000): # page from 1 to 100
#     page = (page-1) * 10   # pagination
#     url = "%s%s%s%d" % (base_url, sort_by, start_from, page) # get full url
#     contents = BeautifulSoup(urllib2.urlopen(url), "lxml")
#
#     contentsElements = contents.find_all('div', attrs={"class" : '  row  result'})
#     cont = contents.find('div', attrs = {'class': 'lastRow  row  result'}) ##just added last job on each page
#     contentsElements.append(cont)
#     # each row contains 1 job
#
#     # extract job information
#     for elem in contentsElements:
#         try:
#             company = elem.find('span', attrs={'itemprop':'name'}).getText().strip() #strips off whitespace
# #           salary = elem.find('table', attrs={'class':'snip'}).getText().strip() #strips off whitespace
#         except AttributeError:
#             company = '-'
#         job_title = elem.find('a', attrs={'class':'turnstileLink'}).attrs['title']
#         home_url = "http://www.indeed.com"
#         job_link = "%s%s" % (home_url,elem.find('a').get('href'))
#         job_addr = elem.find('span', attrs={'itemprop':'addressLocality'}).getText()
#         job_posted = elem.find('span', attrs={'class': 'date'}).getText()
#
#
#            # add a record of job info to our data frame
#
#         df = df.append({'company': company,
#                         'job_title': job_title,
#                         'job_link': job_link,
#                         'job_posted': job_posted,
#                         'job_location': job_addr
#                        }, ignore_index=True)

# %%
df
# Out:
#                                           company  \
# 0                                            TIAA
# 1                                          Huawei
# 2                                      Proofpoint
# 3                             Mobile Defense Inc.
# 4                                        Inficare
# 5                Continental Technology Solutions
# 6                             Cisco Systems, Inc.
# 7                                   Goodway Group
# 8                             The Nielsen Company
# 9                              Axius Technologies
# 10                             Southwest Airlines
# 11                                         Huawei
# 12                                            SAP
# 13                                         NVIDIA
# 14                                      Cognizant
# 15                                            IBM
# 16                                         Nektar
# 17                          Workbridge Associates
# 18                           MacAulay-Brown, Inc.
# 19                                    PerkinElmer
# 20                                  KellyMitchell
# 21                               Workplace Alaska
# 22                         Proteus Digital Health
# 23                                       Sikorsky
# 24                              Mitre Corporation
# 25                                           eBay
# 26                                       WellCare
# 27    Old Dominion University Research Foundation
# 28                                    Centerstone
# 29                           Amazon Corporate LLC
# ...                                           ...
# 9960                            Quest Diagnostics
# 9961                   Celldex Therapeutics, Inc.
# 9962                            Kaiser Permanente
# 9963                Weill Cornell Medical College
# 9964                                       BOEING
# 9965                 Sandia National Laboratories
# 9966                           Quidel Corporation
# 9967                      Spark Therapeutics, Inc
# 9968                          Lucigen Corporation
# 9986                                       Supplier Quality Engineer
# 9987                               QC / Technical Writing Specialist
# 9988                          Senior Scientist (Process Development)
# 9989                                 Senior Research Manager, Genome
#
# [9990 rows x 5 columns]

# %%
# check one entry to verify contents
print df.iloc[6]
# Out:
# company                                                             Cisco Systems, Inc.
# job_link        http://www.indeed.com/rc/clk?jk=6cb402d057d00c35&fccid=dfc44f3b8c44a6db
# job_location                                                               San Jose, CA
# job_posted                                                                  Just posted
# job_title                                       Data Scientist - Technology and Quality
# Name: 6, dtype: object

# %%
# Save the result to CSV
df.to_csv('./indeed_companies.csv', encoding='utf-8')

# %% [markdown]
# Downloading the whole data for Australia. 09/29/2016

# %%
# load the library


df_au = pd.DataFrame()   # create a new data frame
pd.set_option('max_colwidth',500)    # to remove column limit (default is 50. Otherwise, we'll lose some info)


# indeed.com's query url
base_url = 'http://au.indeed.com/jobs?q=Data+Scientist&jt=fulltime'
sort_by = 'date'          # sort by data
start_from = '&start='    # start page number

# %%
for page in range(1,10): # page from 1 to 100 
    page = (page-1) * 10   # pagination
    url = "%s%s%s%d" % (base_url, sort_by, start_from, page) # get full url 
    contents = BeautifulSoup(urllib2.urlopen(url), "lxml") 

    contentsElements_au = contents.find_all('div', attrs={"class" : '  row  result'})
    cont_au = contents.find('div', attrs = {'class': 'lastRow  row  result'}) ##just added last job on each page
    contentsElements_au.append(cont_au)
    # each row contains 1 job

    # extract job information
    for elem in contentsElements_au: 
        try:
            company_au = elem.find('span', attrs={'itemprop':'name'}).getText().strip() #strips off whitespace 
        except AttributeError:
            company = '-'
        job_title_au = elem.find('a', attrs={'class':'turnstileLink'}).attrs['title']
        home_url_au = "http://www.indeed.com"
        job_link_au = "%s%s" % (home_url,elem.find('a').get('href'))
        job_addr_au = elem.find('span', attrs={'itemprop':'addressLocality'}).getText()
        job_posted_au = elem.find('span', attrs={'class': 'date'}).getText()

           # add a record of job info to our data frame

        df_au = df_au.append({'company': company_au, 
                        'job_title': job_title_au, 
                        'job_link': job_link_au, 
                        'job_posted': job_posted_au,
                        'job_location': job_addr_au
                       }, ignore_index=True)
df_au
# Out:
#                                      company  \
# 0                           Virgin Australia
# 1                                 AGL Energy
# 2                                   VicSuper
# 3                           General Assembly
# 4                                      CSIRO
# 5                                   Oneflare
# 6                                  Atlassian
# 7                                         EY
# 8                                      CSIRO
# 9                                 MerchMiner
# 10                              Cover Genius
# 11                       Alluvium Consulting
# 12                             Claim Central
# 13                                    Prospa
# 14                                     CSIRO
# 15                  Delivery Centric Pty Ltd
# 16           Susquehanna International Group
# 17                          TabCorp Holdings
# 18                                  RangTech
# 19                                        EY
# 20     Amazon Web Services Australia Pty Ltd
# 21                       The Cotton On Group
# 22              The University of Queensland
# 23                                  Ambition
# 24        Human Capital Management Australia
# 25                                       IBM
# 26                            NSW Government
# 27                                       PwC
# 28                            Robert Walters
# 29                         Monash University
# ..                                       ...
# 60                                    Hudson
# 61                                     ANSTO
# 62                                ACT Health
# 63                     M2 Telecommunications
# 64                                     CSIRO
# 65                           GOW Recruitment
# 78                 Sydney NSW  30+ days ago
# 79           Darlinghurst NSW     1 day ago
# 80               Brisbane QLD  30+ days ago
# 81              Melbourne VIC  30+ days ago
# 82                Clayton VIC  30+ days ago
# 83                 Sydney NSW   13 days ago
# 84              Melbourne VIC   29 days ago
# 85               Randwick NSW    9 days ago
# 86         Sunshine Coast QLD  30+ days ago
# 87                 Sydney NSW  30+ days ago
# 88                 Sydney NSW   15 days ago
# 89               Brisbane QLD   15 days ago
#
#                                                               job_title
# 0                                                        Data Scientist
# 1                                                        Data Scientist
# 2                                                        Data Scientist
# 3                                     Part Time Data Science Instructor
# 4                                  Postdoctoral Fellow - Data Analytics
# 5                                                        Data Scientist
# 6                                                Data / Product Analyst
# 7                                                        Data Scientist
# 8        CSIRO Postdoctoral Fellow: ASKAP Big Data Innovation Challenge
# 9                                        DATA SCIENTIST/ALGORITHM NINJA
# 10                                      Data Scientists (Several Roles)
# 11                                                   Graduate Scientist
# 12                                 Data Scientist / Senior Data Analyst
# 13                                                       Data Scientist
# 14                                  Research Scientist - Cyber Security
# 15                                                       DATA SCIENTIST
# 16                                      Machine Learning Data Scientist
# 17                                                       Data Scientist
# 18                                                       Data Scientist
# 19       Cyber Data Scientist, Financial Services, Advisory - Australia
# 20                                           Data Scientist - Melbourne
# 21                                               Group - Data Scientist
# 22  Lecturer/Senior Lecturer/Associate Professor in Data Science (ITEE)
# 23                                                       Data Scientist
# 24                                                       Data Scientist
# 25                               Data Scientist - Cognitive & Analytics
# 26                   Senior Scientist (Quality/Environmental Forensics)
# 27             Senior Consultant - Data Analytics - Database/SQL Skills
# 28                                                       Data Scientist
# 29                                Data Visualisation Designer/Developer
# ..                                                                  ...
# 60                                                       Data Scientist
# 61                                                Laboratory Technician
# 62             Health Professional Level 2 - Nuclear Medicine Scientist
# 63                              Reporting Analytics Manager - Melbourne
# 64                           Data61 Undergraduate Vacation Scholarships
# 65                                   Data Scientist (12 month contract)
# 66                                                       Data Scientist
# 67           Algorithm Performance Lead Engineer – Canberra (Australia)
# 68                                                    Data Ops Engineer
# 69                                               iOS and App Developers
# 70         Bioinformatics Research Assistant – Genomics and Epigenetics
# 71    CSIRO Postdoctoral Fellowship-Human Pluripotent Stem Cell Biology
# 72                                            Data Engineer - Melbourne
# 73                                Product Development & Project Manager
# 74                 Frontend Developer, UI Designer, UX - Multiple Roles
# 75          Scala Developer/Big Data Engineer - Multiple roles - Sydney
# 76             Graduate Coastal Engineer or Scientist Sydney, Australia
# 77                          Project Administrator - Facility Operations
# 78                             Data Scientist - Global Research Company
# 79                             Junior Bioinformatics Scientist/Engineer
# 80                                                      Pricing Actuary
# 81                       Data Scientist - Data Extraction and Modelling
# 82                                Research Fellow (Atmospheric Science)
# 83                                                    Big Data Engineer
# 84                                            Quantitative Investigator
# 85                     2X Technical Officer Grade 1/2 (FTE 0.4) Weekend
# 86                                                Production Technician
# 87                                          Growth Team (Several Roles)
# 88                  Lead Data engineer | Big Data | 6-12 Month contract
# 89                               Supervisor Microbiology Specimen Setup
#
# [90 rows x 5 columns]

# %%
# Save the result to CSV
df_au.to_csv('./indeed_companies_au.csv', encoding='utf-8')

# %%
jobs_data = pd.read_csv('indeed_companies.csv')
jobs_data_au = pd.read_csv('indeed_companies_au.csv')
frames = [jobs_data, jobs_data_au]
result = pd.concat(frames, axis = 0, ignore_index = True)
result
# Out:
#        Unnamed: 0                                      company  \
# 0               0                                         TIAA
# 1               1                                       Huawei
# 2               2                                   Proofpoint
# 3               3                          Mobile Defense Inc.
# 4               4                                     Inficare
# 5               5             Continental Technology Solutions
# 6               6                          Cisco Systems, Inc.
# 7               7                                Goodway Group
# 8               8                          The Nielsen Company
# 9               9                           Axius Technologies
# 10             10                           Southwest Airlines
# 11             11                                       Huawei
# 12             12                                          SAP
# 13             13                                       NVIDIA
# 14             14                                    Cognizant
# 15             15                                          IBM
# 16             16                                       Nektar
# 17             17                        Workbridge Associates
# 18             18                         MacAulay-Brown, Inc.
# 19             19                                  PerkinElmer
# 20             20                                KellyMitchell
# 21             21                             Workplace Alaska
# 22             22                       Proteus Digital Health
# 23             23                                     Sikorsky
# 24             24                            Mitre Corporation
# 25             25                                         eBay
# 26             26                                     WellCare
# 27             27  Old Dominion University Research Foundation
# 28             28                                  Centerstone
# 29             29                         Amazon Corporate LLC
# ...           ...                                          ...
# 10050          60                                       Hudson
# 10051          61                                        ANSTO
# 10052          62                                   ACT Health
# 10053          63                        M2 Telecommunications
# 10054          64                                        CSIRO
# 10055          65                              GOW Recruitment
# 10056          66                                     Davidson
# 10057          67                              Seeing Machines
# 10058          68                               Naviro Pty Ltd
# 10059          69                                 Cover Genius
# 10060          70     The Garvan Institute of Medical Research
# 10061          71                                        CSIRO
# 10062          72                        M2 Telecommunications
# 10063          73                                        Xaxis
# 10064          74                                 Cover Genius
# 10065          75                                   Infopeople
# 10066          76                           Baird & Associates
# 10067          77                                        ANSTO
# 10068          78                Keeley Pope Media Recruitment
# 10069          79     The Garvan Institute of Medical Research
# 10070          80                     Auto & General Insurance
# 10071          81                                  Horizon Pty
# 10072          82                            Monash University
# 10073          83                    Aurec Human Capital Group
# 10074          84                              Resources Group
# 10075          85                         NSW Health Pathology
# 10076          86                        Nano-Nouvelle Pty Ltd
# 10077          87                                 Cover Genius
# 10078          88                           Billigence Pty Ltd
# 10079          89                                        Mater
#
#                                                                                                                       job_link  \
# 0                                                      http://www.indeed.com/rc/clk?jk=c13a0f1f2c8f3bcd&fccid=ee5ba787b9f4e31a
# 1                                                      http://www.indeed.com/rc/clk?jk=20589484a63ab6af&fccid=d8be85d73018fac8
# 2                                                      http://www.indeed.com/rc/clk?jk=88441dea622e8a17&fccid=69c7d55b78dc7424
# 3                                                      http://www.indeed.com/rc/clk?jk=8ddae5deb67e7871&fccid=90b9bb2a9e190547
# 4                                                      http://www.indeed.com/rc/clk?jk=dd28a2576d36c5e3&fccid=35781c2041de2a91
# 5                                                      http://www.indeed.com/rc/clk?jk=aab733e36c65e6a7&fccid=664cda5b7c62a987
# 21                                        Research Analyst I/II/III Flex
# 22                Product Data Science Leader (Manager / Senior Manager)
# 23                                                    Database Developer
# 24                                                   Lead Data Scientist
# 25                                                Research Scientist, AI
# 26                                        Claims Coding Research Analyst
# 27                                                    Research Scientist
# 28                                Director of Testing- Flexible Location
# 29                                        Business Intelligence Engineer
# ...                                                                  ...
# 10050                                                     Data Scientist
# 10051                                              Laboratory Technician
# 10052           Health Professional Level 2 - Nuclear Medicine Scientist
# 10053                            Reporting Analytics Manager - Melbourne
# 10054                         Data61 Undergraduate Vacation Scholarships
# 10055                                 Data Scientist (12 month contract)
# 10056                                                     Data Scientist
# 10057         Algorithm Performance Lead Engineer – Canberra (Australia)
# 10058                                                  Data Ops Engineer
# 10059                                             iOS and App Developers
# 10060       Bioinformatics Research Assistant – Genomics and Epigenetics
# 10061  CSIRO Postdoctoral Fellowship-Human Pluripotent Stem Cell Biology
# 10062                                          Data Engineer - Melbourne
# 10063                              Product Development & Project Manager
# 10064               Frontend Developer, UI Designer, UX - Multiple Roles
# 10065        Scala Developer/Big Data Engineer - Multiple roles - Sydney
# 10066           Graduate Coastal Engineer or Scientist Sydney, Australia
# 10067                        Project Administrator - Facility Operations
# 10068                           Data Scientist - Global Research Company
# 10069                           Junior Bioinformatics Scientist/Engineer
# 10070                                                    Pricing Actuary
# 10071                     Data Scientist - Data Extraction and Modelling
# 10072                              Research Fellow (Atmospheric Science)
# 10073                                                  Big Data Engineer
# 10074                                          Quantitative Investigator
# 10075                   2X Technical Officer Grade 1/2 (FTE 0.4) Weekend
# 10076                                              Production Technician
# 10077                                        Growth Team (Several Roles)
# 10078                Lead Data engineer | Big Data | 6-12 Month contract
# 10079                             Supervisor Microbiology Specimen Setup
#
# [10080 rows x 6 columns]

# %% [markdown]
# .

# %%
def extract_text(el):
    if el:
        return el.text.strip()
    else:
        return ''      

def get_company_from_result(result):
    return extract_text(result.find('span', {'class' : 'company'}))

def get_location_from_result(result):
    return extract_text(result.find('span', {'class' : 'location'}))

def get_summary_from_result(result):
    return extract_text(result.find('span', {'class' : 'summary'}))

def get_title_from_result(result):
    return result.find('a', {'data-tn-element' : 'jobTitle'}).text.strip()

def get_salary_from_result(result):
    salary_table = result.find('td', {'class' : 'snip'})
    if salary_table:
        snip = salary_table.find('nobr')
        if snip:
            return snip.text.strip()

    return None


def extract_salary_average(salary_string):
    regex = r'\$([0-9]+,[0-9]+)'
    matches = re.findall(regex, salary_string)
    return np.mean([float(salary.replace(',', '')) for salary in matches ])

# %%
import pandas as pd
from bs4 import BeautifulSoup
import urllib2, requests


url_template = "http://www.indeed.com/jobs?q=data+scientist+${}%2C000&l=USA&start={}"
max_results_per_city = 5000 # Set this to a high-value (5000) to generate more results. 

# Crawling more results, will also take much longer. First test your code on a small number of results and then expand.

#city = elem.find('span', attrs={'itemprop':'addressLocality'}).getText()

rows = []
for salary in set([ '55-70', '70-85', '85-100', '100-115']):
    for start in range(1,10): 
        r = requests.get(url_template.format(salary, start))
        soup = BeautifulSoup(r.content) 
        results = soup.findAll('div', { "class" : "result" })
        for result in results:
            if result:
                row = {}
                row['title'] = get_title_from_result(result)
                row['company'] = get_company_from_result(result)
                row['summary'] = get_summary_from_result(result)
                row['city'] = get_location_from_result(result) 
                row['bin'] = salary
            #row['salary'] = get_salary_from_result(result)
                rows.append(row)

# %%
result = pd.DataFrame.from_records(rows)   # create a new data frame
result.drop_duplicates(subset = "summary")
result
# Out:
#         bin                                        city  \
# 0    85-100           Seattle, WA 98109 (Westlake area)
# 1    85-100                                Dunwoody, GA
# 2    85-100                                  McLean, VA
# 3    85-100                                  Boston, MA
# 4    85-100                                 Atlanta, GA
# 5    85-100                               United States
# 6    85-100                        Burlingame, CA 94010
# 7    85-100                                      Remote
# 8    85-100                             Los Angeles, CA
# 9    85-100           Seattle, WA 98194 (Downtown area)
# 10   85-100                               United States
# 11   85-100           Seattle, WA 98109 (Westlake area)
# 12   85-100                           Redmond, WA 98052
# 13   85-100                        Burlingame, CA 94010
# 14   85-100           Seattle, WA 98194 (Downtown area)
# 15   85-100                          Newtown Square, PA
# 16   85-100                               United States
# 17   85-100                                  Boston, MA
# 18   85-100  Pittsburgh, PA 15222 (Strip District area)
# 19   85-100                              Cary, NC 27513
# 20   85-100           Seattle, WA 98109 (Westlake area)
# 21   85-100                                Dunwoody, GA
# 22   85-100                                  McLean, VA
# 23   85-100                                  Boston, MA
# 24   85-100                                 Atlanta, GA
# 25   85-100                               United States
# 26   85-100                        Burlingame, CA 94010
# 27   85-100                                      Remote
# 28   85-100                             Los Angeles, CA
# 29   85-100           Seattle, WA 98194 (Downtown area)
# ..      ...                                         ...
# 330   55-70                              Los Alamos, NM
# 331   55-70                                 Raleigh, NC
# 332   55-70                               Cambridge, MA
# 333   55-70                               Ann Arbor, MI
# 334   55-70                              Shrewsbury, MA
# 335   55-70                                        Ohio
# 336   55-70                               Cambridge, MA
# 337   55-70                                 Raleigh, NC
# 338   55-70                                New York, NY
# 339   55-70                              Framingham, MA
# 340   55-70                              Los Alamos, NM
# 341   55-70                                 Raleigh, NC
# 342   55-70                               Cambridge, MA
# 343   55-70                               Ann Arbor, MI
# 344   55-70                              Shrewsbury, MA
# 345   55-70                                        Ohio
# 346   55-70                               Cambridge, MA
# 347   55-70                                 Raleigh, NC
# 348   55-70                                New York, NY
# 349   55-70                              Framingham, MA
# 350   55-70                              Los Alamos, NM
# 351   55-70                                 Raleigh, NC
# 352   55-70                               Cambridge, MA
# 353   55-70                               Ann Arbor, MI
# 354   55-70                              Shrewsbury, MA
# 355   55-70                                        Ohio
# 356   55-70                               Cambridge, MA
# 357   55-70                                 Raleigh, NC
# 358   55-70                                New York, NY
# 359   55-70                              Framingham, MA
#
#                                             company  \
# 0                                      Novo Nordisk
# 1    State Farm Mutual Automobile Insurance Company
# 2                                      Byte Systems
# 3                            Physical Sciences Inc.
# 4                                        Home Depot
# 5                                        State Farm
# 6                                         CrowdStar
# 7                                         Crossover
# 8                                       UCLA Health
# 9                      Providence Health & Services
# 10                                       State Farm
# 11                                     Novo Nordisk
# 12                                        Microsoft
# 13                                        CrowdStar
# 14                     Providence Health & Services
# 15                                              SAP
# 16                                    Tuft & Needle
# 17                                  Broad Institute
# 18                                        CompuGain
# 19                                          Verizon
# 20                                     Novo Nordisk
# 21   State Farm Mutual Automobile Insurance Company
# 22                                     Byte Systems
# 23                           Physical Sciences Inc.
# 24                                       Home Depot
# 25                                       State Farm
# 26                                        CrowdStar
# 27                                        Crossover
# 28                                      UCLA Health
# 29                     Providence Health & Services
# ..                                              ...
# 330                  Los Alamos National Laboratory
# 331                                   Resolvit, LLC
# 332                                           KAYAK
# 333                          University of Michigan
# 334      University of Massachusetts Medical School
# 335            Ohio State University Medical Center
# 336                                       KAYAK.com
# 337                                     Grifols: US
# 338                             Columbia University
# 339                                         Staples
# 340                  Los Alamos National Laboratory
# 341                                   Resolvit, LLC
# 342                                           KAYAK
# 343                          University of Michigan
# 344      University of Massachusetts Medical School
# 345            Ohio State University Medical Center
# 346                                       KAYAK.com
# 347                                     Grifols: US
# 348                             Columbia University
# 349                                         Staples
# 350                  Los Alamos National Laboratory
# 351                                   Resolvit, LLC
# 352                                           KAYAK
# 353                          University of Michigan
# 354      University of Massachusetts Medical School
# 355            Ohio State University Medical Center
# 356                                       KAYAK.com
# 357                                     Grifols: US
# 358                             Columbia University
# 359                                         Staples
#
#                                                                                                                                                                  summary  \
# 0                                            Title DATA SCIENTIST. The Data Scientist is expected to:. The Data Scientist reports to a DRI-US Senior Project Manager....
# 1                             Experience w/unstructured data sets:. Our Data Science analysts do much more than just search large data sets & crunch numbers all day!...
# 2    The Sponsor is seeking a Data Scientist. Conduct statistical, mathematical, geospatial modeling or data-mining analysis in partnership with other Data Scientist...
# 3          Physical Sciences Inc., located just north of Boston in Andover, is looking for an individual with strong technical skills in the area of multimodal image...
# 4     Data Scientists are responsible for organizing, analyzing, and then sharing insights gleaned from data. A Data Scientist leverages their technical abilities to...
# 5                             Experience w/unstructured data sets:. Our Data Science analysts do much more than just search large data sets & crunch numbers all day!...
# 6    The Data Scientist will be joining our Data Science team. With millions of users spending 30 to 60 minutes a day within the app, we are poised for expansion and...
# 7        We are looking for a highly experienced Applied Data Scientist enabling and owning lead scoring methods to drive profitable sales growth. About the Company....
# 8      Data cleaning, analysis, manuscript writing, research administration, website development, monitoring students and volunteers, and maintaining study files are...
# 9               The Data Scientist will create databases, conduct appropriate analyses and present data and information in an innovative format for interpretation by...
# 10                            Experience w/unstructured data sets:. Our Data Science analysts do much more than just search large data sets & crunch numbers all day!...
# 11                                           Title DATA SCIENTIST. The Data Scientist is expected to:. The Data Scientist reports to a DRI-US Senior Project Manager....
# 12                                            The data scientist would analyze, optimize and implement models for a diverse range of problems in the Universal Store....
# 13   The Data Scientist will be joining our Data Science team. With millions of users spending 30 to 60 minutes a day within the app, we are poised for expansion and...
# 14              The Data Scientist will create databases, conduct appropriate analyses and present data and information in an innovative format for interpretation by...
# 15                                             For the Data Scientist position we are considering experienced candidates with high analytical problem-solving skills....
# 16                                         Expertise in working with large data sets. Partner with those teams to adjust and design their strategies using such data....
# 17                                            Explore novel data representation modes with emphasis on integrating diverse data types. Analyze data from experiments....
# 18               Summary: Document and identify gaps in IT and business processes through process mapping to illustrate current and future state. Education/ Experience:
# 19                                                    Coordinate data collection on our strategic wireline networks and correlate with existing data in the database....
# 20                                           Title DATA SCIENTIST. The Data Scientist is expected to:. The Data Scientist reports to a DRI-US Senior Project Manager....
# 21                            Experience w/unstructured data sets:. Our Data Science analysts do much more than just search large data sets & crunch numbers all day!...
# 22   The Sponsor is seeking a Data Scientist. Conduct statistical, mathematical, geospatial modeling or data-mining analysis in partnership with other Data Scientist...
# 23         Physical Sciences Inc., located just north of Boston in Andover, is looking for an individual with strong technical skills in the area of multimodal image...
# 24    Data Scientists are responsible for organizing, analyzing, and then sharing insights gleaned from data. A Data Scientist leverages their technical abilities to...
# 25                            Experience w/unstructured data sets:. Our Data Science analysts do much more than just search large data sets & crunch numbers all day!...
# 26   The Data Scientist will be joining our Data Science team. With millions of users spending 30 to 60 minutes a day within the app, we are poised for expansion and...
# 27       We are looking for a highly experienced Applied Data Scientist enabling and owning lead scoring methods to drive profitable sales growth. About the Company....
# 28     Data cleaning, analysis, manuscript writing, research administration, website development, monitoring students and volunteers, and maintaining study files are...
# 29              The Data Scientist will create databases, conduct appropriate analyses and present data and information in an innovative format for interpretation by...
# ..                                                                                                                                                                   ...
# 330     Captures findings and data and plans next stages of technical work upon findings from data. Use epoxy and high strength fiber to reinforce coils wound within...
# 331                                                 Technical knowledge regarding data models, database design development, data mining, and segmentation techniques....
# 332   Investigate data problems, identify patterns. This person should love working on data parsing, analyzing, investigating, interpreting, modeling, and extracting...
# 333  Direct supervision is received from the Data Scientist. Extract data and work with large data sets performing necessary quality checks to ensure data integrity....
# 334                 Responsible for data acquisition, data analysis, and presentation of research results. Prepare and present data for publication in public forums....
# 335                 Performs experiments, collects and analyzes data; Research Scientist to independently perform basic research and develop novel research programs;...
# 336   Investigate data problems, identify patterns. This person should love working on data parsing, analyzing, investigating, interpreting, modeling, and extracting...
# 337   Research Scientist requires a Ph.D. The ability to analyze and interpret data is essential. Presentation of data to and participation on cross-functional teams...
# 338      The successful candidate will play an integral role in cardiovascular precision medicine team science focused on the clinical data, electronic health record...
# 339                                                                                            : Qualifications Job : Location(s) : Other Locations : Schedule : : : ...
# 340     Captures findings and data and plans next stages of technical work upon findings from data. Use epoxy and high strength fiber to reinforce coils wound within...
# 341                                                 Technical knowledge regarding data models, database design development, data mining, and segmentation techniques....
# 342   Investigate data problems, identify patterns. This person should love working on data parsing, analyzing, investigating, interpreting, modeling, and extracting...
# 343  Direct supervision is received from the Data Scientist. Extract data and work with large data sets performing necessary quality checks to ensure data integrity....
# 344                 Responsible for data acquisition, data analysis, and presentation of research results. Prepare and present data for publication in public forums....
# 345                 Performs experiments, collects and analyzes data; Research Scientist to independently perform basic research and develop novel research programs;...
# 346   Investigate data problems, identify patterns. This person should love working on data parsing, analyzing, investigating, interpreting, modeling, and extracting...
# 347   Research Scientist requires a Ph.D. The ability to analyze and interpret data is essential. Presentation of data to and participation on cross-functional teams...
# 348      The successful candidate will play an integral role in cardiovascular precision medicine team science focused on the clinical data, electronic health record...
# 349                                                                                            : Qualifications Job : Location(s) : Other Locations : Schedule : : : ...
# 350     Captures findings and data and plans next stages of technical work upon findings from data. Use epoxy and high strength fiber to reinforce coils wound within...
# 351                                                 Technical knowledge regarding data models, database design development, data mining, and segmentation techniques....
# 352   Investigate data problems, identify patterns. This person should love working on data parsing, analyzing, investigating, interpreting, modeling, and extracting...
# 353  Direct supervision is received from the Data Scientist. Extract data and work with large data sets performing necessary quality checks to ensure data integrity....
# 354                 Responsible for data acquisition, data analysis, and presentation of research results. Prepare and present data for publication in public forums....
# 355                 Performs experiments, collects and analyzes data; Research Scientist to independently perform basic research and develop novel research programs;...
# 356   Investigate data problems, identify patterns. This person should love working on data parsing, analyzing, investigating, interpreting, modeling, and extracting...
# 357   Research Scientist requires a Ph.D. The ability to analyze and interpret data is essential. Presentation of data to and participation on cross-functional teams...
# 358      The successful candidate will play an integral role in cardiovascular precision medicine team science focused on the clinical data, electronic health record...
# 359                                                                                            : Qualifications Job : Location(s) : Other Locations : Schedule : : : ...
#
#                                               title
# 0                                DATA SCIENTIST Job
# 1                                    Data Scientist
# 2                                    Data Scientist
# 3         Image/Sensor Analytics Scientist/Engineer
# 4                       Data Scientist Ops Research
# 5                                    Data Scientist
# 6                                    Data Scientist
# 7                Lead Scoring/Data Scientist - $85K
# 8                            Statistical Researcher
# 9                                    Data Scientist
# 10                                   Data Scientist
# 11                               DATA SCIENTIST Job
# 12    Data Scientist II - Windows and Devices Group
# 13                                   Data Scientist
# 14                                   Data Scientist
# 15      Data Scientist - SAP Custom Development Job
# 16                                   Data Scientist
# 17                 Data Scientist, Machine Learning
# 18                                   Data Scientist
# 19                                   Data Scientist
# 20                               DATA SCIENTIST Job
# 21                                   Data Scientist
# 22                                   Data Scientist
# 23        Image/Sensor Analytics Scientist/Engineer
# 24                      Data Scientist Ops Research
# 25                                   Data Scientist
# 26                                   Data Scientist
# 27               Lead Scoring/Data Scientist - $85K
# 28                           Statistical Researcher
# 29                                   Data Scientist
# ..                                              ...
# 330                 Magnet Lab Tec (Research Tec 3)
# 331                                  Data Scientist
# 332                                  Data Scientist
# 333                                    Data Analyst
# 334                          Research Scientist, Sr
# 335                              Research Scientist
# 336                                  Data Scientist
# 337  Research Scientist / Senior Research Scientist
# 338                       Data Analyst - Cardiology
# 339                  Data Scientist, Framingham, MA
# 340                 Magnet Lab Tec (Research Tec 3)
# 341                                  Data Scientist
# 342                                  Data Scientist
# 343                                    Data Analyst
# 344                          Research Scientist, Sr
# 345                              Research Scientist
# 346                                  Data Scientist
# 347  Research Scientist / Senior Research Scientist
# 348                       Data Analyst - Cardiology
# 349                  Data Scientist, Framingham, MA
# 350                 Magnet Lab Tec (Research Tec 3)
# 351                                  Data Scientist
# 352                                  Data Scientist
# 353                                    Data Analyst
# 354                          Research Scientist, Sr
# 355                              Research Scientist
# 356                                  Data Scientist
# 357  Research Scientist / Senior Research Scientist
# 358                       Data Analyst - Cardiology
# 359                  Data Scientist, Framingham, MA
#
# [360 rows x 5 columns]

# %% [markdown]
# .

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 5 columns):
# bin        360 non-null object
# city       360 non-null object
# company    360 non-null object
# summary    360 non-null object
# title      360 non-null object
# dtypes: object(5)
# memory usage: 14.1+ KB

# %%
# %matplotlib inline
import seaborn
result.bin.value_counts()
# Out:
# 85-100     90
# 100-115    90
# 55-70      90
# 70-85      90
# Name: bin, dtype: int64

# %%
result.company.unique()
# Out:
# array([u'Novo Nordisk', u'State Farm Mutual Automobile Insurance Company',
#        u'Byte Systems', u'Physical Sciences Inc.', u'Home Depot',
#        u'State Farm', u'CrowdStar', u'Crossover', u'UCLA Health',
#        u'Providence Health & Services', u'Microsoft', u'SAP',
#        u'Tuft & Needle', u'Broad Institute', u'CompuGain', u'Verizon',
#        u'Arizona Health Care Cost Containment System', u'NBCUniversal',
#        u'New Mexico State University', u'Sprint',
#        u'Blizzard Entertainment', u'Booz Allen Hamilton', u'Cytel', u'ICF',
#        u'Agilent', u'State of Hawaii', u'BAYER', u'ZirMed', u'Proofpoint',
#        u'Apple', u'Los Alamos National Laboratory', u'Resolvit, LLC',
#        u'KAYAK', u'University of Michigan',
#        u'University of Massachusetts Medical School',
#        u'Ohio State University Medical Center', u'KAYAK.com',
#        u'Grifols: US', u'Columbia University', u'Staples'], dtype=object)

# %%
import nltk
import nltk.stem
import nltk.stem.porter
import nltk.stem.snowball
snowball = nltk.stem.snowball.SnowballStemmer("english")

# %%
junior = str(result[result['bin'].isin(['55-70'])].summary) #subsetting over categories(bins)
mid_low = str(result[result['bin'].isin(['70-85'])].summary)
mid_high = str(result[result['bin'].isin(['85-100'])].summary)
senior = str(result[result['bin'].isin(['100-115'])].summary)

# %%
#junior

# %%
junior_words = nltk.word_tokenize(junior)
mid_low_words = nltk.word_tokenize(mid_low)
mid_high_words = nltk.word_tokenize(mid_high)
senior_words = nltk.word_tokenize(senior)
len(senior_words)
# Out:
# 1586

# %%
from nltk.probability import FreqDist
fdist_junior = FreqDist(junior_words)
sorted(w for w in set(junior_words) if len(w) > 3 and fdist_junior[w] > 15)
# Out:
# ['Scientist', 'data', 'research']

# %%
from nltk.probability import FreqDist
fdist_mid_low = FreqDist(mid_low_words)
sorted(w for w in set(mid_low_words) if len(w) > 3 and fdist_mid_low[w] > 20)
# Out:
# ['analysis', 'business', 'data', 'with']

# %%
from nltk.probability import FreqDist
fdist_mid_high = FreqDist(mid_high_words)
sorted(w for w in set(mid_high_words) if len(w) > 3 and fdist_mid_high[w] > 20)
# Out:
# ['Data', 'Scientist', 'data', 'sets']

# %%
from nltk.probability import FreqDist
fdist_senior = FreqDist(senior_words)
sorted(w for w in set(senior_words) if len(w) > 3 and fdist_senior[w] > 20)
# Out:
# ['Data', 'Scientist', 'data', 'with']

# %%
lr = sklearn.linear_model.LogisticRegression()
lr.fit(titanic[['Age']] ,titanic.Survived)
probabilities = lr.predict_proba([ [age] for age in range(0,101)  ])
matplotlib.pyplot.plot(probabilities)
probabilities
